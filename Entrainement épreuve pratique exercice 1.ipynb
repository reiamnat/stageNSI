# %% [markdown]
# <div style="border-left:5px solid #fdee00; border-radius:2pt; color:#ffffff; padding:16px; background-color: #0068cc">
# <div style="color:#fef86c;">
#
# # Épreuve pratique
# </div>
#
# ## Sujet aléatoire
#
# </div>

# %% [markdown]
# <div style="border-left:3px solid #0068cc; border-radius:2pt; color:#0056b6; padding:16px; background-color: #e8f0f5">
#
# ### Énoncé
# Réinitiliser ce notebook afin de charger la dernière version. (Bouton <button class='fa fa-undo'></button>)
# Exécuter les 2 cellules suivantes et réaliser l'exercice proposé, en vérifiant les tests inclus.
#
# </div>

# %%
from random import choice
liste_epreuves = ['D7XTV', 'DPWQD', 'DMXWR'] # liste mise à jour régulièrement : charger la dernière version
url = 'https://www.codepuzzle.io/I' + choice(liste_epreuves)

# %%
from IPython.display import IFrame
IFrame(url, width='100%', height=900)
# Out:
# <iframe src="https://www.codepuzzle.io/ID7XTV" allowfullscreen="" width="100%" height="900" frameborder="0"></iframe>
