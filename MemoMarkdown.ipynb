# %% [markdown]
# <div class = "alert  alert-info" style="border-left: 3px solid ">
#
# # Mémo Markdown
# ![logo Markdown](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Markdown")
#
#
# **Sommaire**
#
# [1. Titres](#1.-Titres)
# [2. Emphase](#2.-Emphase)
# [3. Listes](#3.-Listes)
# [4. Citation](#4.-Citation)
# [5. Séparateurs horizontaux](#5.-Séparateurs-horizontaux)
# [6. Liens](#6.-Liens)
# [7. Images](#7.-Images)
# [8. Tableaux](#8.-Tableaux)
# [9. Code](#9.-Code)
# [10. Formules LaTeX](#10.-Formules-LaTeX)
# [11. Boites colorées](#11.-Boites-colorées)
# [12. Badges](#12.-Badges)
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 1. Titres
#
# ```md
# # Titre de niveau 1
# ## Titre de niveau 2
# ### Titre de niveau 3
# #### Titre de niveau 4
# ##### Titre de niveau 5
# ###### Titre de niveau 6
# ```
# </div>
#
# # Titre de niveau 1
# ## Titre de niveau 2
# ### Titre de niveau 3
# #### Titre de niveau 4
# ##### Titre de niveau 5
# ###### Titre de niveau 6

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 2. Emphase
#
# ```md
# *Texte en italique*
# **Texte en gras**
# ~~Texte barré~~
# ```
# </div>
#
# *Texte en italique*
# **Texte en gras**
# ~~Texte barré~~

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 3. Listes
# ### 3.1 Listes à puces
# ```md
# * Élément 1
# * Élément 2
#     * Sous-élément 1
#     * Sous élément 2
# * Élément 3
# ```
# </div>
#
# * Élément 1
# * Élément 2
#     * Sous-élément 1
#     * Sous élément 2
# * Élément 3

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### 3.2 Listes ordonnées
# ```md
# 1. Élément 1
# 2. Élément 2
#     1. Sous-élément 1
#     2. Sous élément 2
# 3. Élément 3
# 7. Élément 4 (Le 7 sera corrigé : les éléments sont renumérotés automatiquement)
# ```
# </div>
#
# 1. Élément 1
# 2. Élément 2
#     1. Sous-élément 1
#     2. Sous élément 2
# 3. Élément 3
# 7. Élément 4 (Le 7 sera corrigé : les éléments sont renumérotés automatiquement)

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 4. Citation
# ```md
# > Voici une citation
# > sur plusieurs lignes
# ```
# </div>
#
# > Voici une citation
# > sur plusieurs lignes

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 5. Séparateurs horizontaux
# ```md
# --- ou *** ou ___
# ```
# </div>
#
# ---
# ou
# ***
# ou
# ___

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 6. Liens
# ```md
# [texte du lien](url du lien)
#
# [Ceci est le texte du lien](https://www.carnets.info/jupyter/memomd/)
# [Ceci est un lien avec un titre au survol](https://www.carnets.info/jupyter/memomd/ "Le titre du lien")
# Ceci est un lien automatique : https://www.carnets.info/jupyter/memomd/
#
# ```
# </div>
#
# [Ceci est le texte du lien](https://www.carnets.info/jupyter/memomd/)
#
# [Ceci est un lien avec un titre au survol](https://www.carnets.info/jupyter/memomd/ "Le titre du lien")
#
#  Ceci est un lien automatique : https://www.carnets.info/jupyter/memomd/

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 7. Images
#
# ### 7.1 Markdown
# ```md
# ![](url)
# ![texte alternatif](url "titre au survol")
#
#
# ![logo Markdown](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Markdown")
# ```
# </div>
#
# ![logo Markdown](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Markdown")

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### 7.2 Html
# ```html
# <figure style=... >             /* par exemple : 'float: right;' */
#     <img title='titre au survol'
#          src=url
#          width=... >
#     <figcaption>Légende</figcaption>
# </figure>
# ```
# ---
# ```html
# <figure>
#     <img title='logo Markdown'
#      src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'
#      width='50px' >
#     <figcaption style="text-align: center; font-size: x-small;" >Logo centré</figcaption>
# </figure>
#
# <figure style= 'float: right;'>
# <img title='logo Markdown'
#      src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'
#      width='40px' >
# <figcaption style='font-size: x-small;'>Logo à droite</figcaption>
# </figure>
#
# <figure style= 'float: left;'>
# <img title='logo Markdown'
#      src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'
#      width='40px' >
# <figcaption style='font-size: x-small;'>Logo à gauche</figcaption>
# </figure>
# ```
#
# </div>
# <figure >
# <img title='logo Markdown'
#      src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'
#      width='50px' >
# <figcaption style='text-align: center; font-size: x-small;'>Logo centré</figcaption>
# </figure>
#
# <figure style= 'float: right;'>
# <img title='logo Markdown'
#      src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'
#      width='40px' >
# <figcaption style='font-size: x-small;'>Logo à droite</figcaption>
# </figure>
#
# <figure style= 'float: left;'>
# <img title='logo Markdown'
#      src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'
#      width='40px' >
# <figcaption style='font-size: x-small;'>Logo à gauche</figcaption>
# </figure>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### 7.3 Aligner plusieurs images (Html)
# ```html
# <div style= "display: flex; justify-content: center;"><br>
# <img src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'>
# <img src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'>
# <img src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'>
# <img src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'>
# </div>
# ```
#
#
#
# <div style= "display: flex; justify-content: center;"><br>
# <img src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'><img src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'><img src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'><img src='https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png'>
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 8. Tableaux
# ```md
# Titre colonne 1 (gauche) | Titre colonne 2 (centré) | Titre colonne 3 (droite)
# :--- | :---: | ---:
# Cellule 1.1 | Cellule 1.2 | Cellule 1.3
# Cellule 2.1 | Cellule 2.2 | Cellule 2.3
# ```
# </div>
#
# Titre colonne 1 (gauche) | Titre colonne 2 (centré) | Titre colonne 3 (droite)
# :--- | :---: | ---:
# Cellule 1.1 | Cellule 1.2 | Cellule 1.3
# Cellule 2.1 | Cellule 2.2 | Cellule 2.3

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 9. Code
# ### 9.1 Code en ligne
#
# ```md
# insertion de code en ligne : `print("Hello World!")`
#
# ```
# </div>
#
# insertion de code en ligne : `print("Hello World!")`

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### 9.2 Bloc de code
# ````md
# ```python
# for i in range(5):
#     print("Hello World!")
# ```
# ````
#
# </div>
#
# ```python
# for i in range(5):
#     print("Hello World!")
# ```

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 10. Formules LaTeX
#
# ```md
# Mode en ligne :
# On cherche les solutions de l'équation (E) : $x^2 + 3x - 7 = 0$
#
# Mode bloc (display) :
# On trouve :  $$x = \frac{-3 \pm \sqrt{37}}{2}$$
# ```
# </div>
#
# Mode en ligne :
# On cherche les solutions de l'équation (E) : $x^2 + 3x - 7 = 0$
#
# Mode bloc (display) :
# On trouve :  $$x = \frac{-3 \pm \sqrt{37}}{2}$$

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 11. Boites colorées
#
# ### 11.1 Class Alert
# ```md
# <div class = "alert alert-info"> Boite bleue </div>
# <div class = "alert  alert-success"> Boite verte </div>
# <div class = "alert  alert-warning"> Boite jaune </div>
# <div class = "alert  alert-danger"> Boite rouge </div>
#
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;"> Exemple de style personnalisé</div>
# ```
#
# </div>
#
# <div class = "alert  alert-info"> Boite bleue </div>
# <div class = "alert  alert-success"> Boite verte </div>
# <div class = "alert  alert-warning"> Boite jaune </div>
# <div class = "alert  alert-danger"> Boite rouge </div>
#
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;"> Exemple de style personnalisé</div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### 11.2 Balise Details
# ```md
# <details>
# <summary style="border-left:3px solid #a66207; border-radius:2pt; width:100%; color:#a66207; padding:6px; background-color: #f7debc">
# Aide
# </summary>
#
# <div style="border-left:3px solid #a66207; border-radius:2pt; color:#a66207; padding:6px; background-color: #fcf6ed">
# Indications
# </div>
# </details>
# ```
#
# </div>
#
# <details>
# <summary style="border-left:3px solid #a66207; border-radius:2pt; width:100%; color:#a66207; padding:6px; background-color: #f7debc">
# Aide
# </summary>
#
# <div style="border-left:3px solid #a66207; border-radius:2pt; color:#a66207; padding:6px; background-color: #fcf6ed">
# Indications
# </div>
# </details>

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3c763d; border-radius:2pt; width:100%; color:#3c763d; padding:6px; background-color: #dff0d8">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3c763d; border-radius:2pt; color:#3c763d; padding:6px; background-color: #eff0e8">
#
# Solution
# </div>
# </details>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ## 12. Badges
#
# ```md
# <span class="badge" style="color:#ffffff; background-color: #ee5555">Baccalauréat 2022</span>
# ```
#
# </div>
#
# <span class="badge" style="color:#ffffff; background-color: #ee5555">Baccalauréat 2022</span>
# </div>
